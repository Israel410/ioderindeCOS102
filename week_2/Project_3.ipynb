# %%
# %pip install prettytable
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Python code for tabulating student data(name,age,height and scores)
# It's for 20 students(10 boys and 10 girls)

from prettytable import PrettyTable

print("Table showing the details of the girl in class")
girls = PrettyTable()
girls.add_column("Names",["Evelyn", "Jessica", "Somto", "Edith", "Liza", "Madonna", "Waje", "Tola", "Aisha", "Latifa"])
girls.add_column("Age",["17", "16", "17", "18", "16", "18", "17", "20", "19", "17"])
girls.add_column("Height",["5.5", "6.0", "5.4", "5.9", "5.6", "5.5", "6.1", "6.0", "5.7", "5.5"])
girls.add_column("Scores",["80", "85", "70", "60", "76", "66", "87", "95", "50", "49"])
print(girls)


print("Table showing the details of the boys in the class")
boys=PrettyTable()
boys.add_column("Names",["Chinedu", "Liam", "Wale", "Gbenga", "Abiola", "Kola", "Kunle", "George", "Thomas", "Wesley"])
boys.add_column("Age",["19", "16", "18", "17", "20", "19", "16", "18", "17", "19"])
boys.add_column("Height",["5.7", "5.9", "5.8", "6.1", "5.9", "5.5", "6.1", "5.4", "5.8", "5.7"])
boys.add_column("Scores",["74", "87", "75", "68", "66", "78", "87", "98", "54", "60"])
print(boys)
# Out:
# Table showing the details of the girl in class
# +---------+-----+--------+--------+
# |  Names  | Age | Height | Scores |
# +---------+-----+--------+--------+
# |  Evelyn |  17 |  5.5   |   80   |
# | Jessica |  16 |  6.0   |   85   |
# |  Somto  |  17 |  5.4   |   70   |
# |  Edith  |  18 |  5.9   |   60   |
# |   Liza  |  16 |  5.6   |   76   |
# | Madonna |  18 |  5.5   |   66   |
# |   Waje  |  17 |  6.1   |   87   |
# |   Tola  |  20 |  6.0   |   95   |
# |  Aisha  |  19 |  5.7   |   50   |
# |  Latifa |  17 |  5.5   |   49   |
# +---------+-----+--------+--------+
# Table showing the details of the boys in the class
# +---------+-----+--------+--------+
# |  Names  | Age | Height | Scores |
# +---------+-----+--------+--------+
# | Chinedu |  19 |  5.7   |   74   |
# |   Liam  |  16 |  5.9   |   87   |
# |   Wale  |  18 |  5.8   |   75   |
# |  Gbenga |  17 |  6.1   |   68   |
# |  Abiola |  20 |  5.9   |   66   |
# |   Kola  |  19 |  5.5   |   78   |
# ...
