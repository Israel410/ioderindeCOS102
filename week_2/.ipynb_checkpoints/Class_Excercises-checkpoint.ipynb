# %%
# Python program to swap two cities

# To take inputs from the user
city_1=input("Enter the name of city 1: ")
city_2=input("Enter the name of city 2: ")

# create a temporary variable and swap the cities
temp=city_1
city_1=city_2
city_2=temp

print(f"The name of the city 1 after swapping is {city_1}")
print(f"The name of the city 2 after swapping is {city_2}")
# Out:
# Enter the name of city 1:  kinh
# Enter the name of city 2:  nike
# The name of the city 1 after swapping is nike
# The name of the city 2 after swapping is kinh

# %%
# Program to check if a number is Positive, Negative or 0

num = float(input("Enter a number"))
if num > 0:
    print("Positive number")
    print("Negative number")
else:
    print("The number is 0")
# Out:
# Enter a number 0
# The number is 0

# %%
# COUPE DE ESCRIVIA 2023: FOOTBALL PICKS

print("Welcome to the COUPE DE ESCRIVIA 2023: FOOTBALL PICKS \n")

captain= {'Madiba: ': 'Chubby Obiora-Okafo', 'Blue-Jays: ': 'Christopher Uweh',
          'Cirok: ': 'Alexander', 'TSG Walkers: ': 'Ikechukwu'}

goalkeepers= {'Madiba: ': 'Chubby Obiora-Okafo',
              'Blue-Jays: ': 'Olademeji Abaniwondea/Jeffery Awagu',
              'Cirok: ': 'Timileyin Pearse/Izuako Jeremy',
              'TSG Walkers: ': 'Ayoamide Ojituku'}
for pick in captain:
    print(pick, captain[pick])

print("\n")

for pick in goalkeepers:
    print(pick, goalkeepers[pick])
# Out:
# Welcome to the COUPE DE ESCRIVIA 2023: FOOTBALL PICKS
#
# Madiba:  Chubby Obiora-Okafo
# Blue-Jays:  Christopher Uweh
# Cirok:  Alexander
# TSG Walkers:  Ikechukwu
#
#
# Madiba:  Chubby Obiora-Okafo
# Blue-Jays:  Olademeji Abaniwondea/Jeffery Awagu
# Cirok:  Timileyin Pearse/Izuako Jeremy
# TSG Walkers:  Ayoamide Ojituku
