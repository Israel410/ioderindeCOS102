# %% [markdown]
# PSEUDOCODE FOR STORE CHECKOUT AFTER PURCHASE
# INITIALIZE total_price to zero
# INPUT the price of the first item
# REPEAT while there are more items:
#      *Add item_pricee to total_price
#      *Input the next item_price(or a signal to stop)
# CALCULATE tax(e.g.,total_price *0.05)
# CALCULATE final_amount=total_price+tax
# DISPLAY final_amount
# INPUT payment_received
# CALCULATE change = payment_received-final_amount
# DISPLAY change and "Thank you!"

# %% [markdown]
# ![image.jpg](attachment:0f364bff-39a3-4728-8edf-ac1ebb71107a.jpg)

# %%
PSEUDOCODE SHOWING THE SWAPPING OF AGE AMONGST INDIVIDUALS
INPUT  name1
INPUT  age1
INPUT  name2
INPUT  age2
CREATE a temporary storage valuee called temp
ASSIGN the value of age1 to temp(temp=age1)
ASSIGN the value of age2 to age1 (age1=age2)
ASSIGN the value of temp(which holds the original age1) to age2 (age2=temp)
OUTPUT the new values to confirm the swap
