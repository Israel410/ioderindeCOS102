# %%
# Python code for employing full-stack developer
# at Izifin Technology
def main():
    while True:
        print("Welcome to Izfin Technology")
        print("This calculator helps use know your experience as well as age")
        print("This calculator also helps use calculate your Annual Tax Revenue(ATR) off that")
        
        name=input("Enter your full_name: ")
        exp=int(input("Enter your years of experience: "))   # Enter your years of experience
        age=int(input("Enter your current age: "))   # Enter your age
        
        if exp>25 and age>=55:
            print("Your Annual Tax Return(ATR) is N5,600,000")
        elif exp>20 and age>=45:
            print("Your Annual Tax Return(ATR) is N4,480,000")
        elif exp>10 and age>=35:
             print("Your Annual Tax Return(ATR) is N1,500,000")
        elif exp<10 and age<35:
            print("Your Annual Tax Return(ATR) is N550,000")
        else:
            print("No specific tax bracket found for this criteria")
        
        choice=input("Enter q to quit and r to restart calculator")
        if choice=="q":
            print("Thanks for using this calculator")
            break
        elif choice=="r":
            print("Restarting program...")
            return
        else:
            print("Invalid input try again")
            break
        
    
main()
# Out:
# Welcome to Izfin Technology
# This calculator helps use know your experience as well as age
# This calculator also helps use calculate your Annual Tax Revenue(ATR) off that
# Enter your full_name:  Ixxy Daniels
# Enter your years of experience:  25
# Enter your current age:  55
# Your Annual Tax Return(ATR) is N4,480,000
